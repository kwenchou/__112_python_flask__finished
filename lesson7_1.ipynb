# %%
import requests
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
response = requests.request('GET',url)
if response.status_code == 200:
    print("連線成功")
    all_data = response.json()
    print(type(all_data))
else:
    print(f"連線失敗:{response.status_code}")
# Out:
# 連線成功
# <class 'list'>

# %%
import pandas as pd

dataFrame = pd.DataFrame(data=all_data,columns=['sna','tot','sbi','sarea','mday','ar','bemp','act'])
dataFrame
# Out:
#                            sna  tot  sbi   sarea                 mday
# 0           YouBike2.0_捷運科技大樓站   28    8     大安區  2023-05-27 10:58:13  \
# 1       YouBike2.0_復興南路二段273號前   21    9     大安區  2023-05-27 10:51:15
# 2         YouBike2.0_國北教大實小東側門   16    0     大安區  2023-05-27 10:45:04
# 3            YouBike2.0_和平公園東側   11    2     大安區  2023-05-27 10:49:13
# 4         YouBike2.0_辛亥復興路口西北側   16   12     大安區  2023-05-27 10:58:13
# ...                        ...  ...  ...     ...                  ...
# 1275      YouBike2.0_臺大總圖書館西南側   30   16    臺大專區  2023-05-27 10:57:14
# 1276        YouBike2.0_臺大黑森林西側   20    0    臺大專區  2023-05-27 10:30:28
# 1277        YouBike2.0_臺大獸醫館南側   24    5    臺大專區  2023-05-27 10:57:14
# 1278      YouBike2.0_臺大新體育館東南側   40   24    臺大專區  2023-05-27 10:57:14
# 1279  YouBike2.0_臺大明達館北側(員工宿舍)   18    2  臺大公館校區  2023-05-27 10:35:16
#
#                  ar  bemp act
# 0       復興南路二段235號前    17   1
# 1      復興南路二段273號西側    12   1
# 2       和平東路二段96巷7號    15   1
# 3     和平東路二段118巷33號     9   1
# 4        復興南路二段368號     4   1
# ...             ...   ...  ..
# 1275       臺大圖書館西南側    14   1
# 1276        臺大霖澤館南側    19   1
# 1277       臺大獸醫系館南側    19   1
# 1278        臺大體育館東側    16   1
# 1279       明達館北側前空地    15   1
#
# [1280 rows x 8 columns]

# %%
#選取欄位
dataFrame[['sna', 'tot', 'sbi']]
# Out:
#                            sna  tot  sbi
# 0           YouBike2.0_捷運科技大樓站   28    8
# 1       YouBike2.0_復興南路二段273號前   21    9
# 2         YouBike2.0_國北教大實小東側門   16    0
# 3            YouBike2.0_和平公園東側   11    2
# 4         YouBike2.0_辛亥復興路口西北側   16   12
# ...                        ...  ...  ...
# 1275      YouBike2.0_臺大總圖書館西南側   30   16
# 1276        YouBike2.0_臺大黑森林西側   20    0
# 1277        YouBike2.0_臺大獸醫館南側   24    5
# 1278      YouBike2.0_臺大新體育館東南側   40   24
# 1279  YouBike2.0_臺大明達館北側(員工宿舍)   18    2
#
# [1280 rows x 3 columns]

# %%
#選取列(slice)
dataFrame[67:72]
# Out:
#                            sna  tot  sbi sarea                 mday
# 67    YouBike2.0_敦化南路二段293巷口南側   14    2   大安區  2023-05-27 10:45:14  \
# 68           YouBike2.0_敦化基隆路口   29    2   大安區  2023-05-27 10:55:24
# 69       YouBike2.0_安和路二段181巷口   17    0   大安區  2023-05-27 10:58:13
# 70  YouBike2.0_臨江街夜市(通化街101巷口)   30    3   大安區  2023-05-27 10:58:13
# 71       YouBike2.0_臨江街夜市(基隆路)   17    1   大安區  2023-05-27 10:57:14
#
#                ar  bemp act
# 67  敦化南路二段293巷口南側    12   1
# 68     敦化南路二段218號    25   1
# 69      安和路二段185號    17   1
# 70        通化街111號    25   1
# 71      基隆路二段108號    13   1
