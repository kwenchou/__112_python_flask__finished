# %%
import requests
url = 'https://data.ntpc.gov.tw/api/datasets/71cd1490-a2df-4198-bef1-318479775e8a/csv?size=1000'

#下載資料
response = requests.get(url)
if response.ok:
    print(response.text)

# %%
from io import StringIO
import csv
file = StringIO(response.text,newline='')
csv_reader = csv.DictReader(file)
csv_list = list(csv_reader)
for item_dict in csv_list:
    print(item_dict)

# %%
import pandas as pd
df = pd.DataFrame(data=csv_list)
df.drop(columns=['sareaen','snaen','aren','lat','lng'])
# Out:
#     ﻿"sno"            sna tot sbi sarea            mday
# 0     1001           大鵬華城  12   7   新店區  20230520153438  \
# 1     1002          汐止火車站  24  15   汐止區  20230520153448
# 2     1003          汐止區公所  24  15   汐止區  20230520153421
# 3     1004         國泰綜合醫院  28  12   汐止區  20230520153433
# 4     1006   捷運大坪林站(5號出口)  26   7   新店區  20230520153441
# ..     ...            ...  ..  ..   ...             ...
# 640   1760          龍米停車場  20   5   八里區  20230520153437
# 641   1761           雙和醫院  18   0   中和區  20230520153425
# 642   1762       寶高智慧產業園區  54  19   新店區  20230520153421
# 643   1763    捷運三重站(1號出口)  22   4   三重區  20230520153437
# 644   1766  捷運三民高中站(2號出口)  22  14   蘆洲區  20230520153429
#
#                                   ar bemp act
# 0                    新北市新店區中正路700巷3號    5   1
# 1                     南昌街/新昌路口(西側廣場)    7   1
# 2    新台五路一段/仁愛路口(新台五路側汐止地政事務所前機車停車場)    9   1
# 3                        建成路78號對面停車場   11   1
# 4                      中興路三段224號(對面)   17   1
# ..                               ...  ...  ..
# 640                     龍米路二段150號(旁)   14   1
# 641                    中正路281號(公車亭旁)   17   1
# 642                        寶高路10號(旁)   35   1
# 643                        捷運路36號(旁)   18   1
# 644                          復興路58號旁    7   1
#
# [645 rows x 9 columns]
